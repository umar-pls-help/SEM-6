# %%
#Part 1: How to load data file(s) using Pandas?

# %%
import pandas as pd
import numpy
import scipy

# %%
df=pd.read_csv("Customer.csv")

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size Graduated
# 0        Healthcare                1            4       Yes
# 1          Engineer                3            3       Yes
# 2          Engineer                1            1        No
# 3            Lawyer                0            2        No
# 4     Entertainment                2            6        No
# ...             ...              ...          ...       ...
# 1995         Artist                8            7        No
# 1996         Doctor                7            7        No
# 1997     Healthcare                9            2        No
# 1998      Executive                7            2       Yes
# 1999  Entertainment                5            2        No
#
# [2000 rows x 9 columns]

# %%
backup_df = df

# %%
#Part 2: How to convert a variable to a different data type?

# %%
#Convert numeric variables to string variables and vice versa

numeric_input = 10
string_input = "12"

string_outcome = str(numeric_input) #Converts numeric_input to string_outcome
integer_outcome = int(string_input) #Converts string_input to integer_outcome
float_outcome = float(string_input) #Converts string_input to integer_outcome

print(string_outcome ,"Type is:", type(string_outcome))
print(integer_outcome,"Type is:", type(integer_outcome))
print(float_outcome,"Type is:", type(float_outcome))
# Out:
# 10 Type is: <class 'str'>
# 12 Type is: <class 'int'>
# 12.0 Type is: <class 'float'>

# %%
#Convert character date to Date:

from datetime import datetime
char_date = 'April 1 2015 1:20 PM' #creating example character date

# %B	Month name, long version
# %b	Month name, short version
# %d	Day of month 01-31
# %Y	Year, full version
# %I	Hour 00-12
# %M	Minute 00-59
# %p	AM/PM

date_obj = datetime.strptime(char_date, '%B %d %Y %I:%M %p')
print(date_obj)
# Out:
# 2015-04-01 13:20:00

# %%
#Part 3: How to transpose a Data set or dataframe using Pandas?

# %%
#Transposing Pandas dataframe by a variable
result= df.pivot( columns='Profession', values='Annual Income ($)')
result
# Out:
# Profession  NaN    Artist   Doctor  Engineer  Entertainment  Executive  \
# 0           NaN       NaN      NaN       NaN            NaN        NaN
# 1           NaN       NaN      NaN   35000.0            NaN        NaN
# 2           NaN       NaN      NaN   86000.0            NaN        NaN
# 3           NaN       NaN      NaN       NaN            NaN        NaN
# 4           NaN       NaN      NaN       NaN        38000.0        NaN
# ...         ...       ...      ...       ...            ...        ...
# 1995        NaN  184387.0      NaN       NaN            NaN        NaN
# 1996        NaN       NaN  73158.0       NaN            NaN        NaN
# 1997        NaN       NaN      NaN       NaN            NaN        NaN
# 1998        NaN       NaN      NaN       NaN            NaN   182109.0
# 1999        NaN       NaN      NaN       NaN       110610.0        NaN
#
# Profession  Healthcare  Homemaker   Lawyer  Marketing
# 0              15000.0        NaN      NaN        NaN
# 1                  NaN        NaN      NaN        NaN
# 2                  NaN        NaN      NaN        NaN
# 3                  NaN        NaN  59000.0        NaN
# 4                  NaN        NaN      NaN        NaN
# ...                ...        ...      ...        ...
# 1995               NaN        NaN      NaN        NaN
# 1996               NaN        NaN      NaN        NaN
# 1997           90961.0        NaN      NaN        NaN
# 1998               NaN        NaN      NaN        NaN
# 1999               NaN        NaN      NaN        NaN
#
# [2000 rows x 10 columns]

# %%
#Part 4: How to sort a Pandas DataFrame?

# %%
#Sorting Pandas Dataframe
df.sort_values(['Annual Income ($)','Age'], ascending=[True, False])
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 169          170    Male   32                  0                      63
# 246          247    Male   23                  0                      96
# 272          273  Female   96               1000                      76
# 96            97  Female   47               2000                      47
# 113          114    Male   19               2000                      46
# ...          ...     ...  ...                ...                     ...
# 638          639  Female   59             189672                       8
# 1576        1577  Female   16             189689                      37
# 1825        1826    Male    7             189709                      18
# 1257        1258    Male   60             189945                      20
# 569          570  Female   91             189974                      37
#
#          Profession  Work Experience  Family Size Graduated
# 169          Artist                2            2       Yes
# 246          Doctor                1            3        No
# 272   Entertainment                0            3        No
# 96           Artist                0            1       Yes
# 113          Artist                1            1       Yes
# ...             ...              ...          ...       ...
# 638          Doctor                0            7        No
# 1576     Healthcare                8            5       Yes
# 1825         Artist                6            6       Yes
# 1257       Engineer                0            5       Yes
# 569        Engineer                8            1       Yes
#
# [2000 rows x 9 columns]

# %%
df.sort_values(['Age'], ascending=True)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 443          444  Female    0              68761                      16
# 466          467    Male    0             186002                      80
# 1271        1272  Female    0              61228                      81
# 1248        1249  Female    0             143082                      63
# 1583        1584  Female    0             120899                       7
# ...          ...     ...  ...                ...                     ...
# 1629        1630    Male   99             162762                      52
# 1188        1189  Female   99             122548                      14
# 351          352    Male   99             173394                       4
# 361          362    Male   99              63364                      61
# 347          348  Female   99             184426                      41
#
#          Profession  Work Experience  Family Size Graduated
# 443          Lawyer                1            4       Yes
# 466          Doctor               15            2        No
# 1271  Entertainment                1            6        No
# 1248  Entertainment                0            7       Yes
# 1583      Marketing                2            6       Yes
# ...             ...              ...          ...       ...
# 1629     Healthcare                1            1       Yes
# 1188            NaN                2            5        No
# 351        Engineer               13            1       Yes
# 361   Entertainment                1            2        No
# 347          Artist                9            1        No
#
# [2000 rows x 9 columns]

# %%
#Part 5: How to create plots (Histogram, Scatter, Box Plot)?

# %%
#Plot Histogram
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#Plots in matplotlib reside within a figure object, use plt.figure to create new figure
fig=plt.figure()

#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)

#Variable
ax.hist(df['Age'],bins = 5)
#Labels and Title
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter plot:

# %%
#Plots in matplotlib reside within a figure object, use plt.figure to create new figure
fig=plt.figure()
#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)
#Variable
ax.scatter(df['Age'],df['Annual Income ($)'])
#Labels and Title
plt.title('Annual Income ($) and Age distribution')
plt.xlabel('Age')
plt.ylabel('Annual Income ($)')
plt.show()

# %%
#Box-plot:

# %%
import seaborn as sns
sns.boxplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#Part 6: How to generate frequency tables with Pandas?

# %%
import pandas as pd

df=pd.read_csv("Customer.csv")
test= df.groupby(['Gender','Profession'])
test.size()
# Out:
# Gender  Profession
# Female  Artist           380
#         Doctor            89
#         Engineer         103
#         Entertainment    133
#         Executive         87
#         Healthcare       196
#         Homemaker         39
#         Lawyer            86
#         Marketing         53
# Male    Artist           232
#         Doctor            72
#         Engineer          76
#         Entertainment    101
#         Executive         66
#         Healthcare       143
#         Homemaker         21
#         Lawyer            56
#         Marketing         32
# dtype: int64

# %%
#Part 7: How to do sample Data set in Python?

# %%
#Create Sample dataframe
import numpy as np
import pandas as pd
from random import sample
dfr = df.sample(n=10)
#print(dfr)
dfr.head(10)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 482          483    Male   76             155622                      81
# 164          165    Male   50              47000                      26
# 1064        1065    Male   23             122712                      21
# 1764        1765  Female   63             176783                      40
# 90            91  Female   68              46000                      55
# 187          188    Male   28              44000                      68
# 332          333    Male   84             137641                      67
# 605          606  Female    3             155864                      31
# 1220        1221    Male   68             170957                       6
# 1750        1751    Male   79              95839                      30
#
#          Profession  Work Experience  Family Size Graduated
# 482      Healthcare                0            2       Yes
# 164          Doctor                0            2        No
# 1064      Marketing                1            1       Yes
# 1764         Doctor                9            4       Yes
# 90    Entertainment                0            3       Yes
# 187          Doctor                5            3       Yes
# 332      Healthcare                0            5       Yes
# 605      Healthcare               13            3        No
# 1220         Lawyer                1            3       Yes
# 1750      Executive                7            2        No

# %%
#Part 8: How to remove duplicate values of a variable in a Pandas Dataframe?

# %%
# Before Removing any duplicates
df.shape
# Out:
# (2000, 9)

# %%
#Remove Duplicate Values based on values of variables "Gender" and "Profession"
rem_dup=df.drop_duplicates(['Gender', 'Profession'])
rem_dup.head(20)
#rem_dup.shape
# Out:
#      CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0             1    Male   19              15000                      39
# 1             2    Male   21              35000                      81
# 2             3  Female   20              86000                       6
# 3             4  Female   23              59000                      77
# 4             5  Female   31              38000                      40
# 5             6  Female   22              58000                      76
# 6             7  Female   35              31000                       6
# 12           13  Female   58              80000                      15
# 14           15    Male   37              19000                      13
# 16           17  Female   35              29000                      35
# 18           19    Male   52              20000                      29
# 20           21    Male   35              96000                      35
# 23           24    Male   31              71000                      73
# 31           32  Female   21              34000                      73
# 54           55  Female   50              18000                      45
# 59           60    Male   53              89000                      46
# 79           80  Female   49              98000                      42
# 103         104    Male   26              52000                      55
# 138         139    Male   19              22000                      10
# 237         238    Male   95              36000                      35
#
#         Profession  Work Experience  Family Size Graduated
# 0       Healthcare                1            4       Yes
# 1         Engineer                3            3       Yes
# 2         Engineer                1            1        No
# 3           Lawyer                0            2        No
# 4    Entertainment                2            6        No
# 5           Artist                0            2       Yes
# 6       Healthcare                1            3       Yes
# 12       Executive                0            5       Yes
# 14          Doctor                0            1        No
# 16       Homemaker                9            5       Yes
# 18   Entertainment                1            4       Yes
# 20       Homemaker               12            1        No
# 23          Artist                5            2        No
# 31          Doctor                1            2       Yes
# 54       Marketing                1            1       Yes
# 59          Lawyer                1            6       Yes
# 79             NaN                1            1       Yes
# 103      Executive                0            5       Yes
# 138      Marketing                8            4       Yes
# 237            NaN                0            4        No

# %%
#Part 9: How to group variables in Pandas to calculate count, average, sum?

# %%
test = df.groupby(['Profession'])
test.describe()
# Out:
#               CustomerID                                                 \
#                    count         mean         std   min     25%     50%
# Profession
# Artist             612.0   994.034314  585.230026   6.0  473.50  1007.0
# Doctor             161.0  1010.571429  582.629135  15.0  505.00  1052.0
# Engineer           179.0   935.692737  583.085006   2.0  372.50   916.0
# Entertainment      234.0  1061.166667  544.322702   5.0  641.50  1048.0
# Executive          153.0  1072.254902  594.153882  13.0  596.00  1117.0
# Healthcare         339.0   970.876106  562.578312   1.0  501.50   950.0
# Homemaker           60.0  1022.916667  622.422721  17.0  482.25   975.5
# Lawyer             142.0   957.401408  595.812813   4.0  412.75   944.5
# Marketing           85.0  1038.211765  570.284684  55.0  585.00   947.0
#
#                                   Age             ... Work Experience        \
#                    75%     max  count       mean  ...             75%   max
# Profession                                        ...
# Artist         1484.25  1996.0  612.0  49.004902  ...             7.0  17.0
# Doctor         1493.00  1997.0  161.0  46.621118  ...             8.0  16.0
# Engineer       1453.00  1995.0  179.0  55.094972  ...             7.0  16.0
# Entertainment  1541.00  2000.0  234.0  51.162393  ...             7.0  15.0
# Executive      1611.00  1999.0  153.0  46.601307  ...             8.0  16.0
# Healthcare     1436.50  1998.0  339.0  47.843658  ...             7.5  16.0
# Homemaker      1640.50  1967.0   60.0  45.366667  ...             9.0  14.0
# Lawyer         1440.75  1985.0  142.0  47.753521  ...             7.0  17.0
# Marketing      1561.00  1993.0   85.0  45.823529  ...             8.0  15.0
#
#               Family Size
#                     count      mean       std  min  25%  50%   75%  max
# Profession
# Artist              612.0  3.653595  1.940423  1.0  2.0  3.0  5.00  8.0
# Doctor              161.0  3.670807  2.066931  1.0  2.0  3.0  6.00  7.0
# Engineer            179.0  3.581006  1.933698  1.0  2.0  4.0  5.00  8.0
# Entertainment       234.0  3.888889  1.983960  1.0  2.0  4.0  6.00  7.0
# Executive           153.0  3.967320  1.868782  1.0  3.0  4.0  5.00  7.0
# Healthcare          339.0  3.905605  1.943719  1.0  2.0  4.0  5.50  8.0
# Homemaker            60.0  4.050000  2.142587  1.0  2.0  4.0  6.25  7.0
# Lawyer              142.0  3.619718  2.075635  1.0  2.0  3.0  5.75  9.0
# Marketing            85.0  3.729412  1.941945  1.0  2.0  3.0  5.00  7.0
#
# [9 rows x 48 columns]

# %%
#Part 10: How to recognize and Treat missing values and outliers in Pandas?

# %%
# Identify missing values of dataframe
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# Graduated                 17
# dtype: int64

# %%
#Part 11: How to merge / join data sets and Pandas dataframes?

# %%
df_new = pd.merge(df, dfr, how = 'inner', left_index = True, right_index = True)
df_new
# Out:
#       CustomerID_x Gender_x  Age_x  Annual Income ($)_x  \
# 90              91   Female     68                46000
# 164            165     Male     50                47000
# 187            188     Male     28                44000
# 332            333     Male     84               137641
# 482            483     Male     76               155622
# 605            606   Female      3               155864
# 1064          1065     Male     23               122712
# 1220          1221     Male     68               170957
# 1750          1751     Male     79                95839
# 1764          1765   Female     63               176783
#
#       Spending Score (1-100)_x   Profession_x  Work Experience_x  \
# 90                          55  Entertainment                  0
# 164                         26         Doctor                  0
# 187                         68         Doctor                  5
# 332                         67     Healthcare                  0
# 482                         81     Healthcare                  0
# 605                         31     Healthcare                 13
# 1064                        21      Marketing                  1
# 1220                         6         Lawyer                  1
# 1750                        30      Executive                  7
# 1764                        40         Doctor                  9
#
#       Family Size_x Graduated_x  CustomerID_y Gender_y  Age_y  \
# 90                3         Yes            91   Female     68
# 164               2          No           165     Male     50
# 187               3         Yes           188     Male     28
# 332               5         Yes           333     Male     84
# 482               2         Yes           483     Male     76
# 605               3          No           606   Female      3
# 1064              1         Yes          1065     Male     23
# 1220              3         Yes          1221     Male     68
# 1750              2          No          1751     Male     79
# 1764              4         Yes          1765   Female     63
#
#       Annual Income ($)_y  Spending Score (1-100)_y   Profession_y  \
# 90                  46000                        55  Entertainment
# 164                 47000                        26         Doctor
# 187                 44000                        68         Doctor
# 332                137641                        67     Healthcare
# 482                155622                        81     Healthcare
# 605                155864                        31     Healthcare
# 1064               122712                        21      Marketing
# 1220               170957                         6         Lawyer
# 1750                95839                        30      Executive
# 1764               176783                        40         Doctor
#
#       Work Experience_y  Family Size_y Graduated_y
# 90                    0              3         Yes
# 164                   0              2          No
# 187                   5              3         Yes
# 332                   0              5         Yes
# 482                   0              2         Yes
# 605                  13              3          No
# 1064                  1              1         Yes
# 1220                  1              3         Yes
# 1750                  7              2          No
# 1764                  9              4         Yes

# %%
df_new.shape
# Out:
# (10, 18)
